# %%
#Import libraries
import pandas as pd
import numpy as np
import os

# %%
#import data
path = r'C:\Users\alexa\OneDrive\Documents\data analytics\Achievement 4\01-09-2022 Instacart Basket Analysis'

# %%
df_ords = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
#4 question: check shape of 'orders_products_combined'

# %%
df_ords.shape
# Out:
# (32640698, 12)

# %% [markdown]
# it matches

# %%
#5 Question: first imported the 'products_checked.csv' and see compatibility

# %%
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %%
df_ords.head()
# Out:
#    order_id  user_id eval_set  order_number  Order_day_of_week  \
# 0   2539329        1    prior             1                  2
# 1   2539329        1    prior             1                  2
# 2   2539329        1    prior             1                  2
# 3   2539329        1    prior             1                  2
# 4   2539329        1    prior             1                  2
#
#    order_hour_of_day  Days since last order  New customer  product_id  \
# 0                  8                    NaN          True       196.0
# 1                  8                    NaN          True     14084.0
# 2                  8                    NaN          True     12427.0
# 3                  8                    NaN          True     26088.0
# 4                  8                    NaN          True     26405.0
#
#    add_to_cart_order  reordered _merge
# 0                1.0        0.0   both
# 1                2.0        0.0   both
# 2                3.0        0.0   both
# ...

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_prods = df_prods.drop(df_prods.columns[[0]], axis=1)

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %% [markdown]
# the way to merge both data sets is to merge them using 'product_id'

# %%
#5/6 Question: to the merge and verify with the merge flag. first drop the merge column in df_ords

# %%
df_ords = df_ords.drop(columns = ['_merge'])

# %%
df_ords.head()
# Out:
#    order_id  user_id eval_set  order_number  Order_day_of_week  \
# 0   2539329        1    prior             1                  2
# 1   2539329        1    prior             1                  2
# 2   2539329        1    prior             1                  2
# 3   2539329        1    prior             1                  2
# 4   2539329        1    prior             1                  2
#
#    order_hour_of_day  Days since last order  New customer  product_id  \
# 0                  8                    NaN          True       196.0
# 1                  8                    NaN          True     14084.0
# 2                  8                    NaN          True     12427.0
# 3                  8                    NaN          True     26088.0
# 4                  8                    NaN          True     26405.0
#
#    add_to_cart_order  reordered
# 0                1.0        0.0
# 1                2.0        0.0
# 2                3.0        0.0
# ...

# %%
df_merged_large = df_ords.merge(df_prods, on = 'product_id', indicator = True)

# %%
#6 question: merge verification

# %%
df_merged_large.head()
# Out:
#    order_id  user_id eval_set  order_number  Order_day_of_week  \
# 0   2539329        1    prior             1                  2
# 1   2398795        1    prior             2                  3
# 2    473747        1    prior             3                  3
# 3   2254736        1    prior             4                  4
# 4    431534        1    prior             5                  4
#
#    order_hour_of_day  Days since last order  New customer  product_id  \
# 0                  8                    NaN          True       196.0
# 1                  7                   15.0         False       196.0
# 2                 12                   21.0         False       196.0
# 3                  7                   29.0         False       196.0
# 4                 15                   28.0         False       196.0
#
#    add_to_cart_order  reordered product_name  aisle_id  department_id  prices  \
# 0                1.0        0.0         Soda        77              7     9.0
# ...

# %%
df_merged_large['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
#7 question: export merged data

# %%
df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
